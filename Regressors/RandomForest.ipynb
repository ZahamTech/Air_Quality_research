# %% [markdown]
# ## Random Forest

# %%
# Importing Necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score ,mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset 
# Select features (X) and target variable (y)
testing_data=pd.read_csv('testing_data.csv')
training_data= pd.read_csv('new1.csv')
# Training data
X_train = training_data[['co', 'no2', 'o3', 'pm10', 'pm25', 'so2']]  # Features for training
y_train = training_data['aqi']  # Target variable (AQI) for training

# Testing data
X_test = testing_data[['co', 'no2', 'o3', 'pm10', 'pm25', 'so2']]  # Features for testing
y_test = testing_data['aqi']  # Target variable (AQI) for testing
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_16076\1359625343.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   training_data= pd.read_csv('new1.csv')

# %%
# Initialize the RandomForestRegressor model
model = RandomForestRegressor(n_estimators=10, random_state=42)

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
# Make predictions
y_pred = model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
score = model.score(X_test, y_test)
# Display the  results
print(f'Root Mean Squared Error: {rmse}')
print(f"R-squared: {r2}")
print(f"Score of Random Forest : {score*100}%")
print(f"Mean Absolute Error: {mae}")
# Out:
# Root Mean Squared Error: 12.645022637111234
# R-squared: 0.9454178870479698
# Score of Random Forest : 94.54178870479699%
# Mean Absolute Error: 1.2872445532963475

# %%
# Plotting Actual vs Predicted AQI
plt.figure(figsize=(6,3))
plt.plot(y_test.values[:500], label='Actual AQI')
plt.plot(y_pred[:500], label='Predicted AQI', linestyle='--')
plt.title('Actual vs Predicted AQI')
plt.xlabel('Samples')
plt.ylabel('aqi')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
df= training_data
correlation_matrix = df[['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'aqi']].corr()

# %%
# Print the correlation matrix
# print(correlation_matrix)
df= training_data

# %%
# Plot the correlation matrix
plt.figure(figsize=(6, 4.5))

# %%
# Use seaborn heatmap for better visualization
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
# Adding title
plt.title('Correlation Matrix of Features', fontsize=10)
plt.figure(figsize=(6, 4.5))
# Display the plot
plt.show()
