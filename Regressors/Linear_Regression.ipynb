# %% [markdown]
# ## Linear Regression

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset 
# Select features (X) and target variable (y)
testing_data=pd.read_csv('testing_data.csv')
training_data= pd.read_csv('new1.csv')
# Training data
X_train = training_data[['co', 'no2', 'o3', 'pm10', 'pm25', 'so2']]  # Features for training
y_train = training_data['aqi']  # Target variable (AQI) for training

# Testing data
X_test = testing_data[['co', 'no2', 'o3', 'pm10', 'pm25', 'so2']]  # Features for testing
y_test = testing_data['aqi']  # Target variable (AQI) for testing
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6864\1359625343.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   training_data= pd.read_csv('new1.csv')

# %%
# Create and train the Linear Regression model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions
y_pred = lr_model.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
score = lr_model.score(X_test, y_test)

# %%
# Print evaluation metrics
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R-squared: {r2}")
print(f"Score of Linear Regression : {score*100}%")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 1143.5777371458005
# Root Mean Squared Error: 33.81682624294895
# R-squared: 0.6096296594364359
# Score of Linear Regression : 60.96296594364359%
# Mean Absolute Error: 20.526533905553976

# %%
# Plotting Actual vs Predicted AQI
plt.figure(figsize=(6,3))
plt.plot(y_test.values[:500], label='Actual AQI')
plt.plot(y_pred[:500], label='Predicted AQI', linestyle='--')
plt.title('Actual vs Predicted AQI')
plt.xlabel('Samples')
plt.ylabel('aqi')
plt.legend()
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = df[['temp', 'co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'aqi']].corr()
# Use seaborn heatmap for better visualization
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
# Adding title
plt.title('Correlation Matrix of Features', fontsize=10)
plt.figure(figsize=(6, 4.5))
# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Compute the correlation matrix
# ----> 2 correlation_matrix = df[['temp', 'co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'aqi']].corr()
#       3 # Use seaborn heatmap for better visualization
#       4 sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
#
# NameError: name 'df' is not defined
